# %%
n = ...
m = ...

K = IntegerModRing(n)
print("start")
print(K(m).nth_root(18))
# Out:
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/repl/ipython_kernel/__main__.py:4: RuntimeWarning: cypari2 leaked 79297152 bytes on the PARI stack
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-1e7ec9983b7b> in <module>
#       2 m = Integer([0;...)
#       3
# ----> 4 K = GF(n)
#       5 print("start")
#       6 print(K(m).nth_root(Integer(18)))
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/structure/factory.pyx in sage.structure.factory.UniqueFactory.__call__ (build/cythonized/sage/structure/factory.c:2180)()
#     365             False
#     366         """
# --> 367         key, kwds = self.create_key_and_extra_args(*args, **kwds)
#     368         version = self.get_version(sage_version)
#     369         return self.get_object(version, key, kwds)
#
# ...
